# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
sns.set(color_codes=True)

# %%
train_user_ad = pd.read_csv('../data/dup/train_user_ad.csv')

# %%
train_user_ad.head()
# Out:
#    label  clickTime  conversionTime  creativeID   userID  positionID  \
# 0      0     170000             NaN        3089  2798058         293
# 1      0     170000             NaN        1259   463234        6161
# 2      0     170000             NaN        4465  1857485        7434
# 3      0     170000             NaN        1004  2038823         977
# 4      0     170000             NaN        1887  2015141        3688
#
#    connectionType  telecomsOperator  age  gender  education  marriageStatus  \
# 0               1                 1   25       2          1               3
# 1               1                 2   20       2          1               1
# 2               4                 1   16       1          1               0
# 3               1                 1    0       0          0               0
# 4               1                 1   35       1          2               2
#
#    haveBaby  hometown  residence  adID  camgaignID  advertiserID  appID  \
# ...

# %%
d = train_user_ad[['adID','label']][train_user_ad['label']==0]
d['count']=1
xx = d.groupby(['adID','label'],as_index=False).sum()
print xx.shape
xx.head()
# Out:
# (2571, 3)
#    adID  label  count
# 0     1      0     22
# 1     2      0     39
# 2     3      0     14
# 3     4      0     83
# 4     5      0      4

# %%
d = train_user_ad[['adID','label']][train_user_ad['label']==1]
d['count']=1
xx = d.groupby(['adID','label'],as_index=False).sum()
print xx.shape
xx.head()
# Out:
# (1467, 3)
#    adID  label  count
# 0     2      1      1
# 1     9      1      2
# 2    12      1      7
# 3    13      1      1
# 4    14      1      2

# %%
x = train_user_ad[train_user_ad['label']==1]['age']
sns.distplot(x,color='r',label='label=1',kde=False)
x = train_user_ad[train_user_ad['label']==0]['age']
sns.distplot(x,color='b',label='label=0',kde=False)

# %%
x = train_user_ad[train_user_ad['label']==1]['age']
sns.kdeplot(x,color='r',label='label=1')
x = train_user_ad[train_user_ad['label']==0]['age']
sns.kdeplot(x,color='b',label='label=0')

# %%
sns.countplot(x='haveBaby',hue='label',data=train_user_ad)

# %%
sns.countplot(x='marriageStatus',hue='label',data=train_user_ad)

# %%
sns.countplot(x='education',hue='label',data=train_user_ad)

# %%
sns.countplot(x='gender',hue='label',data=train_user_ad)

# %%
train = pd.read_csv('../data/dup/train_time.csv')
train.head()
# Out:
#    label  clickTime  conversionTime  creativeID   userID  positionID  \
# 0      0     170000             NaN        3089  2798058         293
# 1      0     170000             NaN        1259   463234        6161
# 2      0     170000             NaN        4465  1857485        7434
# 3      0     170000             NaN        1004  2038823         977
# 4      0     170000             NaN        1887  2015141        3688
#
#    connectionType  telecomsOperator
# 0               1                 1
# 1               1                 2
# 2               4                 1
# 3               1                 1
# 4               1                 1

# %%
train[train['label']==1].shape
# Out:
# (93261, 8)

# %%
train[(train['label']==1)&(train['connectionType']==1)].shape
# Out:
# (87555, 8)

# %%
sns.countplot(x='connectionType',hue='label',data=train)

# %%
sns.barplot(x='connectionType',y='label',hue='connectionType',data=train,color='g')
plt.show()

# %%
sns.countplot(x='telecomsOperator',hue='label',data=train)
